# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/MR.AMAN SAINI/Downloads/IMDB Top 250 Movies.csv')

# %%
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df.columns
# Out:
# Index(['rank', 'name', 'year', 'rating', 'genre', 'certificate', 'run_time',
#        'tagline', 'budget', 'box_office', 'casts', 'directors', 'writers'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         250 non-null    int64
#  1   name         250 non-null    object
#  2   year         250 non-null    int64
#  3   rating       250 non-null    float64
#  4   genre        250 non-null    object
#  5   certificate  250 non-null    object
#  6   run_time     250 non-null    object
#  7   tagline      250 non-null    object
#  8   budget       250 non-null    object
#  9   box_office   250 non-null    object
#  10  casts        250 non-null    object
#  11  directors    250 non-null    object
#  12  writers      250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %%
df.describe()
# Out:
#              rank         year      rating
# count  250.000000   250.000000  250.000000
# mean   125.500000  1986.360000    8.307200
# std     72.312977    25.125356    0.229081
# min      1.000000  1921.000000    8.000000
# 25%     63.250000  1966.250000    8.100000
# 50%    125.500000  1994.000000    8.200000
# 75%    187.750000  2006.000000    8.400000
# max    250.000000  2022.000000    9.300000

# %%
df.dtypes[df.dtypes=='object']
# Out:
# name           object
# genre          object
# certificate    object
# run_time       object
# tagline        object
# budget         object
# box_office     object
# casts          object
# directors      object
# writers        object
# dtype: object

# %%
df['certificate'].value_counts()
# Out:
# R                97
# PG               37
# PG-13            35
# Not Rated        24
# G                19
# Passed           16
# Approved         14
# Not Available     1
# Unrated           1
# GP                1
# TV-PG             1
# TV-MA             1
# X                 1
# 18+               1
# 13+               1
# Name: certificate, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# 8.1    68
# 8.2    55
# 8.3    38
# 8.4    30
# 8.5    22
# 8.6    13
# 8.8     7
# 8.0     5
# 9.0     5
# 8.7     4
# 8.9     1
# 9.3     1
# 9.2     1
# Name: rating, dtype: int64

# %%
df[df['rating']>=9.2]
# Out:
#    rank                      name  year  rating        genre certificate  \
# 0     1  The Shawshank Redemption  1994     9.3        Drama           R
# 1     2             The Godfather  1972     9.2  Crime,Drama           R
#
#   run_time                                            tagline    budget  \
# 0   2h 22m  Fear can hold you prisoner. Hope can set you f...  25000000
# 1   2h 55m                         An offer you can't refuse.   6000000
#
#   box_office                                              casts  \
# 0   28884504  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 1  250341816  Marlon Brando,Al Pacino,James Caan,Diane Keato...
#
#               directors                          writers
# 0        Frank Darabont      Stephen King,Frank Darabont
# 1  Francis Ford Coppola  Mario Puzo,Francis Ford Coppola

# %%
df[df['rating']<=8.0]
# Out:
#      rank                name  year  rating                       genre  \
# 226   227     The Incredibles  2004     8.0  Animation,Action,Adventure
# 243   244       Life of Brian  1979     8.0                      Comedy
# 247   248             Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249              Gandhi  1982     8.0     Biography,Drama,History
# 249   250  Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate run_time                                            tagline  \
# 226          PG   1h 55m                                       Save The Day
# 243           R   1h 34m  A motion picture destined to offend nearly two...
# 247           G   1h 30m                     Wish granted! (DVD re-release)
# 248          PG   3h 11m             His Triumph Changed The World Forever.
# 249       PG-13    3h 1m  Inside everyone is a frontier waiting to be di...
#
#        budget     box_office  \
# 226  92000000      631607053
# ...

# %%
df['box_office1'] = df['box_office'].replace({'Not Available':0})

# %%
df['budget1'] = df['budget'].replace({'Not':0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         250 non-null    int64
#  1   name         250 non-null    object
#  2   year         250 non-null    int64
#  3   rating       250 non-null    float64
#  4   genre        250 non-null    object
#  5   certificate  250 non-null    object
#  6   run_time     250 non-null    object
#  7   tagline      250 non-null    object
#  8   budget       250 non-null    object
#  9   box_office   250 non-null    object
#  10  casts        250 non-null    object
#  11  directors    250 non-null    object
#  12  writers      250 non-null    object
#  13  box_office1  250 non-null    object
#  14  budget1      250 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 29.4+ KB

# %%
c = pd.DataFrame(df)

# %%
df = c.astype({"budget1": 'int64', "box_office1": 'int64'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         250 non-null    int64
#  1   name         250 non-null    object
#  2   year         250 non-null    int64
#  3   rating       250 non-null    float64
#  4   genre        250 non-null    object
#  5   certificate  250 non-null    object
#  6   run_time     250 non-null    object
#  7   tagline      250 non-null    object
#  8   budget       250 non-null    object
#  9   box_office   250 non-null    object
#  10  casts        250 non-null    object
#  11  directors    250 non-null    object
#  12  writers      250 non-null    object
#  13  box_office1  250 non-null    int64
#  14  budget1      250 non-null    int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 29.4+ KB

# %%
df2 = df['earning'] = df['box_office1'] - df['budget1']

# %%
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
d = df['genre'].value_counts()

# %%
d.head(50)
# Out:
# Drama                         19
# Crime,Drama                   14
# Animation,Adventure,Comedy    10
# Biography,Drama,History        9
# Crime,Drama,Mystery            9
# Drama,War                      8
# Drama,Romance                  6
# Crime,Drama,Thriller           5
# Animation,Action,Adventure     5
# Action,Adventure,Drama         5
# Action,Adventure,Sci-Fi        5
# Action,Crime,Drama             5
# Action,Adventure,Fantasy       5
# Comedy,Drama                   4
# Biography,Crime,Drama          4
# Drama,Mystery,Thriller         4
# Comedy,Drama,Romance           4
# Drama,Thriller                 4
# Mystery,Thriller               3
# Drama,Mystery                  3
# Crime,Thriller                 3
# Adventure,Drama,War            3
# Action,Biography,Drama         3
# Action,Sci-Fi                  3
# Action,Drama                   3
# Adventure,Biography,Drama      3
# Animation,Adventure,Family     3
# Action,Drama,Sci-Fi            3
# ...

# %%
max(df['earning'])
# Out:
# 2443439100

# %%
df[df['earning']==2443439100]
# Out:
#     rank               name  year  rating                   genre certificate  \
# 77    78  Avengers: Endgame  2019     8.4  Action,Adventure,Drama       PG-13
#
#    run_time             tagline     budget  box_office  \
# 77    3h 1m  Avenge the fallen.  356000000  2799439100
#
#                                                 casts  \
# 77  Robert Downey Jr.,Chris Evans,Mark Ruffalo,Chr...
#
#                   directors                                      writers  \
# 77  Anthony Russo,Joe Russo  Christopher Markus,Stephen McFeely,Stan Lee
#
#     box_office1    budget1     earning
# 77   2799439100  356000000  2443439100

# %%
min(df['earning'])
# Out:
# -2229994125

# %%
df[df['earning']==-2229994125]
# Out:
#     rank               name  year  rating                       genre  \
# 78    79  Princess Mononoke  1997     8.4  Animation,Action,Adventure
#
#    certificate run_time   tagline      budget box_office  \
# 78       PG-13   2h 14m  Live on.  2400000000  170005875
#
#                                                 casts       directors  \
# 78  Yôji Matsuda,Yuriko Ishida,Yûko Tanaka,Billy C...  Hayao Miyazaki
#
#                        writers  box_office1     budget1     earning
# 78  Hayao Miyazaki,Neil Gaiman    170005875  2400000000 -2229994125

# %%
df[df['genre']=='Drama']
# Out:
#      rank                             name  year  rating  genre certificate  \
# 0       1         The Shawshank Redemption  1994     9.3  Drama           R
# 11     12                       Fight Club  1999     8.8  Drama           R
# 17     18  One Flew Over the Cuckoo's Nest  1975     8.7  Drama         18+
# 66     67                  American Beauty  1999     8.4  Drama           R
# 84     85              Requiem for a Dream  2000     8.3  Drama     Unrated
# 87     88                        Capernaum  2018     8.4  Drama           R
# 93     94                         The Hunt  2012     8.3  Drama           R
# 99    100                            Ikiru  1952     8.3  Drama   Not Rated
# 113   114                     A Separation  2011     8.3  Drama       PG-13
# 120   121                  Bicycle Thieves  1948     8.3  Drama   Not Rated
# 130   131                    All About Eve  1950     8.2  Drama      Passed
# ...

# %%
df.groupby('genre').mean().sort_values('rating',ascending=False).head(10)
# Out:
#                            rank    year  rating   box_office1      budget1  \
# genre
# Adventure,Western          10.0  1966.0     8.8  2.525389e+07    1200000.0
# Action,Adventure,Drama     28.8  2005.0     8.7  1.259042e+09  148000000.0
# Adventure,Drama,Sci-Fi     25.0  2014.0     8.6  7.738672e+08  165000000.0
# Drama,Family,Fantasy       21.0  1946.0     8.6  8.574081e+06    3180000.0
# Crime,Drama,Fantasy        27.0  1999.0     8.6  2.868014e+08   60000000.0
# Action,Drama,Mystery       57.5  1982.5     8.5  7.710613e+06    1500000.0
# Animation,Adventure,Drama  36.0  1994.0     8.5  9.685118e+08   45000000.0
# Drama,Music                42.0  2014.0     8.5  4.939675e+07    3300000.0
# Drama,Mystery,Sci-Fi       41.0  2006.0     8.5  1.096763e+08   40000000.0
# Drama,Mystery,War          53.0  1979.0     8.5  1.048809e+08   31500000.0
#
#                                 earning
# genre
# Adventure,Western          2.405389e+07
# Action,Adventure,Drama     1.111042e+09
# ...

# %%
df.groupby('genre').mean().sort_values('earning',ascending=False).head(10)
# Out:
#                              rank    year    rating   box_office1  \
# genre
# Action,Adventure,Drama       28.8  2005.0  8.700000  1.259042e+09
# Animation,Adventure,Drama    36.0  1994.0  8.500000  9.685118e+08
# Action,Adventure,Fantasy    102.6  1992.8  8.380000  8.729981e+08
# Action,Adventure,Sci-Fi      96.8  2004.4  8.380000  9.090774e+08
# Action,Drama                 65.0  1996.0  8.433333  8.567496e+08
# Adventure,Family,Fantasy    201.5  1975.0  8.100000  6.839988e+08
# Adventure,Drama,Sci-Fi       25.0  2014.0  8.600000  7.738672e+08
# Animation,Adventure,Comedy  150.5  2006.8  8.210000  6.015109e+08
# Adventure,Thriller          204.0  1975.0  8.100000  4.765121e+08
# Horror                      226.0  1973.0  8.100000  4.413061e+08
#
#                                  budget1       earning
# genre
# Action,Adventure,Drama      1.480000e+08  1.111042e+09
# Animation,Adventure,Drama   4.500000e+07  9.235118e+08
# Action,Adventure,Fantasy    8.030000e+07  7.926981e+08
# ...
